# %%
#Change to your $WORK_DIR. The syntax for switching directories in R is a little different than what we used in bash. 
#Use the "setwd" command to switch to your $WORK_DIR 
sunetid="annashch"
work_dir=paste("/scratch/",sunetid,sep="")
setwd(work_dir)
#The "dir" command will list all files in your current working directory 
dir()
# Out:
#   [1] "all_merged.peaks.bed"
#   [2] "all_peaks.togene.txt"
#   [3] "all.fc.bigwig"
#   [4] "all.fc.txt"
#   [5] "all.peaks.bed"
#   [6] "all.peaks.sorted.bed"
#   [7] "all.readcount.txt"
#   [8] "all.tagAlign.files.txt"
#   [9] "background.txt"
#  [10] "cromwell_input.json"
#  [11] "cromwell_input.json~"
#  [12] "data"
#  [13] "foreground.negative.txt"
#  [14] "foreground.positive.txt"
#  [15] "fraglength.1.txt"
#  [16] "fraglength.2.txt"
#  [17] "fraglength.png"
#  [18] "fraglength.txt"
#  [19] "HOG1_0min_vs_45min.negative.pilot.txt"
#  [20] "HOG1_0min_vs_45min.negative.txt"
#  [21] "HOG1_0min_vs_45min.positive.pilot.txt"
#  [22] "HOG1_0min_vs_45min.positive.txt"
#  [23] "homer_SKN7_0min_vs_45min_negative"
#  [24] "HOT1_0min_vs_45min.negative.pilot.txt"
#  [25] "HOT1_0min_vs_45min.negative.txt"
#  [26] "HOT1_0min_vs_45min.positive.pilot.txt"
#  [27] "HOT1_0min_vs_45min.positive.txt"
#  [28] "MSN1_0min_vs_45min.negative.pilot.txt"
#  [29] "MSN1_0min_vs_45min.negative.txt"
#  [30] "MSN1_0min_vs_45min.positive.pilot.txt"
#  [31] "MSN1_0min_vs_45min.positive.txt"
#  [32] "MSN2_0min_vs_45min.negative.pilot.txt"
#  [33] "MSN2_0min_vs_45min.negative.txt"
#  [34] "MSN2_0min_vs_45min.positive.pilot.txt"
#  [35] "MSN2_0min_vs_45min.positive.txt"
#  [36] "MSN4_0min_vs_45min.negative.pilot.txt"
#  [37] "MSN4_0min_vs_45min.negative.txt"
#  [38] "MSN4_0min_vs_45min.positive.pilot.txt"
#  [39] "MSN4_0min_vs_45min.positive.txt"
#  [40] "narrowPeak_files.txt"
#  [41] "pc1_contribs.ascending.geneonly.txt"
#  [42] "pc1_contribs.ascending.togene.txt"
#  [43] "pc1_contribs.descending.geneonly.txt"
#  [44] "pc1_contribs.descending.togene.txt"
#  [45] "pc1_contribs.sorted.txt"
#  [46] "pc1_contribs.togene.txt"
#  [47] "pc1_contribs.txt"
#  [48] "pc2_contribs.txt"
#  [49] "pc3_contribs.txt"
#  [50] "SKN7_0min_vs_45min.negative.pilot.txt"
#  [51] "SKN7_0min_vs_45min.negative.txt"
#  [52] "SKN7_0min_vs_45min.positive.pilot.txt"
#  [53] "SKN7_0min_vs_45min.positive.txt"
#  [54] "src"
#  [55] "Strain_WT_vs_HOG1.differential.negative.pilot.txt"
#  [56] "Strain_WT_vs_HOG1.differential.negative.txt"
#  [57] "Strain_WT_vs_HOG1.differential.positive.pilot.txt"
#  [58] "Strain_WT_vs_HOG1.differential.positive.txt"
#  [59] "Strain_WT_vs_HOT1.differential.negative.pilot.txt"
#  [60] "Strain_WT_vs_HOT1.differential.negative.txt"
#  [61] "Strain_WT_vs_HOT1.differential.positive.pilot.txt"
#  [62] "Strain_WT_vs_HOT1.differential.positive.txt"
#  [63] "Strain_WT_vs_MSN1.differential.negative.pilot.txt"
#  [64] "Strain_WT_vs_MSN1.differential.negative.txt"
#  [65] "Strain_WT_vs_MSN1.differential.positive.pilot.txt"
#  [66] "Strain_WT_vs_MSN1.differential.positive.txt"
#  [67] "Strain_WT_vs_MSN2.differential.negative.pilot.txt"
#  [68] "Strain_WT_vs_MSN2.differential.negative.txt"
#  [69] "Strain_WT_vs_MSN2.differential.positive.pilot.txt"
#  [70] "Strain_WT_vs_MSN2.differential.positive.txt"
#  [71] "Strain_WT_vs_MSN4.differential.negative.pilot.txt"
#  [72] "Strain_WT_vs_MSN4.differential.negative.txt"
#  [73] "Strain_WT_vs_MSN4.differential.positive.pilot.txt"
#  [74] "Strain_WT_vs_MSN4.differential.positive.txt"
#  [75] "Strain_WT_vs_SKN7.differential.negative.pilot.txt"
#  [76] "Strain_WT_vs_SKN7.differential.negative.txt"
#  [77] "Strain_WT_vs_SKN7.differential.positive.pilot.txt"
#  [78] "Strain_WT_vs_SKN7.differential.positive.txt"
#  [79] "Strain_WT_vs_YAP1.differential.negative.pilot.txt"
#  [80] "Strain_WT_vs_YAP1.differential.negative.txt"
#  [81] "Strain_WT_vs_YAP1.differential.positive.pilot.txt"
#  [82] "Strain_WT_vs_YAP1.differential.positive.txt"
#  [83] "Strain_WT_vs_YAP6.differential.negative.pilot.txt"
#  [84] "Strain_WT_vs_YAP6.differential.negative.txt"
#  [85] "Strain_WT_vs_YAP6.differential.positive.pilot.txt"
#  [86] "Strain_WT_vs_YAP6.differential.positive.txt"
#  [87] "Strain_WT_vs_YAP7.differential.negative.pilot.txt"
#  [88] "Strain_WT_vs_YAP7.differential.negative.txt"
#  [89] "Strain_WT_vs_YAP7.differential.positive.pilot.txt"
#  [90] "Strain_WT_vs_YAP7.differential.positive.txt"
#  [91] "tmp"
#  [92] "WT_0min_vs_45min.differential.negative.togene.txt"
#  [93] "WT_0min_vs_45min.differential.positive.togene.txt"
#  [94] "WT_0min_vs_45min.negative.pilot.txt"
#  [95] "WT_0min_vs_45min.negative.txt"
#  [96] "WT_0min_vs_45min.positive.pilot.txt"
#  [97] "WT_0min_vs_45min.positive.txt"
#  [98] "YAP1_0min_vs_45min.negative.pilot.txt"
#  [99] "YAP1_0min_vs_45min.negative.txt"
# [100] "YAP1_0min_vs_45min.positive.pilot.txt"
# [101] "YAP1_0min_vs_45min.positive.txt"
# [102] "YAP6_0min_vs_45min.negative.pilot.txt"
# [103] "YAP6_0min_vs_45min.negative.txt"
# [104] "YAP6_0min_vs_45min.positive.pilot.txt"
# [105] "YAP6_0min_vs_45min.positive.txt"
# [106] "YAP7_0min_vs_45min.negative.pilot.txt"
# [107] "YAP7_0min_vs_45min.negative.txt"
# [108] "YAP7_0min_vs_45min.positive.pilot.txt"
# [109] "YAP7_0min_vs_45min.positive.txt"
